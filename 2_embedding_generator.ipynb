# %% [markdown]
# # Part 2 Embedding generator
# In this notebook, you will transform the raw web pages scraped from the HKU Innovation Wing and InnoAcademy into a **vector database** ready for Retrieval-Augmented Generation (RAG).
#
# ### What you will learn
# - Why we need to **chunk** long documents
# - How to use `RecursiveCharacterTextSplitter` effectively
# - How to generate high-quality embeddings using Azure OpenAI
# - How to store and manage vectors in **ChromaDB**
# - Best practices for deterministic IDs and fresh ingestion
#
# By the end of this notebook, you will have a searchable vector database (`Innowing_db`) that a chatbot can query intelligently.

# %% [markdown]
# ## 2.1. Introduction – From Raw Text to Vector Database
#
# After scraping websites, we have raw HTML-cleaned text.
# However, large language models have limited context windows and cannot efficiently search through thousands of words at once.
#
# **Solution**:
# 1. **Split** documents into smaller, meaningful **chunks**
# 2. **Convert** each chunk into a dense vector (embedding)
# 3. **Store** vectors + metadata in a vector database (ChromaDB)
#
# This process is the foundation of modern **Retrieval-Augmented Generation (RAG)** systems.

# %% [markdown]
# ## 2.2. Install and Import Libraries
#
# We use the following key packages:
# - **`langchain-text-splitters`** → intelligent document chunking
# - **`openai`** (Azure) → generate high-quality embeddings
# - **`chromadb`** → persistent vector database
# - **`python-dotenv`** → securely load API keys
#
# Run the cell below to ensure all dependencies are installed.

# %%
# %pip install langchain chromadb langchain-text-splitters python-dotenv openai
# Out:
# Requirement already satisfied: langchain in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.2.15)
# Requirement already satisfied: chromadb in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.5.8)
# Requirement already satisfied: langchain-text-splitters in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.1.2)
# Requirement already satisfied: python-dotenv in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.2.2)
# Requirement already satisfied: openai in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.32.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain) (1.2.31)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.32)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.13.0)
# Requirement already satisfied: certifi in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: build>=1.0.3 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.42.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (2.4.4)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (1.41.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai) (0.14.0)
# Requirement already satisfied: sniffio in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: pyproject_hooks in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: sympy in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-proto==1.41.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.62b0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lautl\appdata\roaming\python\python314\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.11.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.28.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.4.3)
# Requirement already satisfied: click>=8.2.1 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lautl\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
import os
import json
import hashlib
from openai import AzureOpenAI
from typing import List, Dict
from langchain_text_splitters import RecursiveCharacterTextSplitter
import chromadb
# Out:
# c:\Users\lautl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %% [markdown]
# ## 2.3. Set Up Your Azure OpenAI API Key
#
# **Security Best Practice**<br>
# Never hard-code your API key in the notebook.
#
# **Step-by-step instructions:**
# 1. Create a new file named **`.env`** in the **same folder** as this notebook (if you haven’t already).
# 2. Open the `.env` file and add the following line:
#
# ```env
# AZURE_OPENAI_API_KEY=your_actual_azure_openai_api_key_here
# ```
#
# 3. Save the file. The notebook will automatically load your key using `python-dotenv`.
#
# **Tips:**
# 1. Make sure the file is named exactly .env (with the dot at the beginning).
# 2. Do not upload this to GitHub or share it publicly (very important!).
# 3.  You should have received your personal API key through email. Each student will have 1 million tokens to use. Please do not share your API key with anyone else, or you risk someone else using up all your tokens.

# %% [markdown]
# ## 2.4. Load Scraped Documents
#
# We load the `data.json` file generated by the web scraper notebook.
#
# **Important**: Always inspect your data before processing!

# %%
load_dotenv()

DATASET = os.getenv("DATASET") or "data.json"  # Changed to data.json as requested
EMBEDDING_MODEL = os.getenv("EMBEDDING_MODEL") or "text-embedding-3-small"
CHROMA_PATH = os.getenv("CHROMA_PATH") or "chroma_db/chroma_db"

if os.path.exists(DATASET):
    print(f"📂 Loading documents from {DATASET}...")
    with open(DATASET, "r", encoding="utf-8") as f:
        documents: List[Dict] = json.load(f)
    print(f"   Loaded {len(documents)} raw pages.")
else:
    raise FileNotFoundError(
        f"❌ {DATASET} not found. Please run your scraper first to generate data.json (or set OUTPUT_FILE env var)."
    )
# Out:
# 📂 Loading documents from data.json...
#    Loaded 150 raw pages.

# %% [markdown]
# Check your data before moving to the next step.

# %%
# print the first document
print(documents[0])
# Out:
# {'url': 'https://innowings.engg.hku.hk/', 'text': 'Innovation Wing\nSkip to content\nThe Tam Wing Fan Innovation Wing One\nprovides an open environment to foster\ninterdisciplinary innovations among\nundergraduate students\nand teachers in Engineering and Technology. The provision of state-of-the-art facilities in a collaborative space will enable curriculum innovations that emphasize hands-on and experiential learning activities. The Innovation Wing serves as a platform to engage the young generation to explore the world, create opportunities for them to learn about the needs of the underprivileged, and acquire practical hands-on experience in developing solutions with real-world impact.\nInnovation Wing One\nThe Tam Wing Fan Innovation Wing Two\naims to serve as an enabling platform for Engineering\nresearchers\nto interact and collaborate synergistically with researchers and professionals across various disciplines to tackle grand challenges and deliver research outputs with significant impact to Hong Kong and global communities, and at the same time to share the Faculty’s latest research achievements/findings/outputs with the large HKU and Hong Kong communities in widely accessible forms for example exhibitions and talks on research topics.\nInnovation Wing Two\nCopyright © 2026 Tam Wing Fan Innovation Wing, Faculty of Engineering, The University of Hong Kong\nFor inquiries please contact Dr. C.K. Chui (innowing[at]hku.hk), the Director of the Tam Wing Fan Innovation Wing.'}

# %% [markdown]
# ## 2.5. Text Chunking – Why and How
#
# Long documents must be split into smaller pieces (chunks) because:
# - Embeddings perform better on focused, coherent text
# - LLMs have token limits
# - Smaller chunks improve retrieval precision
#
# We use **`RecursiveCharacterTextSplitter`** — the industry best practice.
# It tries to split on paragraphs → sentences → words while preserving meaning.
#
# **Key parameters**:
# - `chunk_size=1000` characters (~250–300 tokens)
# - `chunk_overlap=300` characters (prevents loss of context across chunks)

# %%
print("\n🔪 Chunking documents using RecursiveCharacterTextSplitter (best-practice settings)...")

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=300,
    length_function=len,
    separators=["\n\n", "\n", ". ", " ", ""],  # Hierarchical splitting
)

all_texts: List[str] = []
all_metadatas: List[Dict] = []
all_ids: List[str] = []

for doc in documents:
    url = doc["url"]
    text = doc.get("text", "").strip()
    if not text:
        continue

    chunks = text_splitter.split_text(text)

    for chunk_idx, chunk in enumerate(chunks):
        # Deterministic ID (hash of URL + chunk index) → safe re-ingest / upsert
        id_str = f"{url}:{chunk_idx}"
        chunk_id = hashlib.md5(id_str.encode("utf-8")).hexdigest()

        all_texts.append(chunk)
        all_metadatas.append({
            "url": url,
            "source": "HKU InnoWings / InnoAcademy",
            "chunk_index": chunk_idx,
            "total_chunks_on_page": len(chunks),   # useful for debugging / future hierarchical RAG
        })
        all_ids.append(chunk_id)

print(f"Created {len(all_texts)} chunks from {len(documents)} documents.")
# Out:
# 🔪 Chunking documents using RecursiveCharacterTextSplitter (best-practice settings)...
# Created 1560 chunks from 150 documents.

# %% [markdown]
# ## 2.6.Set Up Azure OpenAI Client
#
# We now load your API key from the `.env` file and create the Azure OpenAI client.
#
# If you see an error about a missing API key, double-check that you have created the `.env` file correctly in the same folder as this notebook.

# %%
API_Key = os.getenv("AZURE_OPENAI_API_KEY")
if not API_Key:
    raise RuntimeError("Missing Azure OpenAI credentials.")

client = AzureOpenAI(
    azure_endpoint="https://api-iw.azure-api.net/sig-embedding/openai/deployments/text-embedding-3-small/embeddings?api-version=2024-10-21",
    api_key=API_Key,
    api_version="2024-10-21",
)

def get_embedding(text: str) -> List[float]:
    response = client.embeddings.create(
        input=[text.replace("\n", " ")],
        model=EMBEDDING_MODEL,
    )
    return response.data[0].embedding

# %% [markdown]
# ## 2.7. ChromaDB Vector Database Setup
#
# **ChromaDB** is a lightweight, developer-friendly, and persistent vector database that is perfect for building local RAG applications.
#
# In this step we will:
# - Connect to (or create) a persistent ChromaDB instance on disk
# - Delete any existing collection to ensure a **clean, fresh ingestion** (useful during development)
# - Create a new collection named `Innowing_db`
# - Configure it to use **cosine similarity** as the distance metric — the standard and recommended choice for text embeddings
#
# This setup allows us to efficiently store and later retrieve semantically similar chunks when the chatbot needs to answer questions.

# %%
chroma_client = chromadb.PersistentClient(path=CHROMA_PATH)

COLLECTION_NAME = "Innowing_db"

try:
    chroma_client.delete_collection(name=COLLECTION_NAME)
    print(f"🗑️  Deleted existing collection '{COLLECTION_NAME}' for fresh ingest.")
except:
    pass

collection = chroma_client.get_or_create_collection(
    name=COLLECTION_NAME,
    metadata={"hnsw:space": "cosine"}
)
# Out:
# 🗑️  Deleted existing collection 'Innowing_db' for fresh ingest.

# %% [markdown]
# ## 2.8. Generate Embeddings and Store in ChromaDB
#
# Now comes the core part of the pipeline:
#
# 1. We generate a high-quality embedding vector for **every text chunk** using Azure OpenAI’s `text-embedding-3-small` model.
# 2. We store each embedding together with:
#    - The original text (document)
#    - Rich metadata (URL, source, chunk index, etc.)
#    - A deterministic unique ID (so we can safely re-run this notebook without duplicates)
#
# We process the chunks in **batches of 50** to:
# - Respect API rate limits
# - Keep memory usage reasonable
# - Provide clearer progress feedback
#
# This step may take a few minutes depending on your internet connection and Azure quota.
# Once completed, your vector database will be ready for semantic search and RAG!

# %%
print("🧬 Generating embeddings and storing in ChromaDB (this may take a while)...")

BATCH_SIZE = 50

for i in range(0, len(all_texts), BATCH_SIZE):
    batch_texts = all_texts[i : i + BATCH_SIZE]
    batch_metadatas = all_metadatas[i : i + BATCH_SIZE]
    batch_ids = all_ids[i : i + BATCH_SIZE]

    # Generate embeddings for the batch
    embeddings = [get_embedding(text) for text in batch_texts]

    # Use .upsert() instead of .add() → industry standard for idempotent ingestion
    collection.upsert(
        embeddings=embeddings,
        documents=batch_texts,
        metadatas=batch_metadatas,
        ids=batch_ids
    )

    print(f"  [{i + len(batch_texts)}/{len(all_texts)}] Added batch to ChromaDB")

print("\n🎉 Ingestion complete!")
print(f"   ChromaDB collection '{COLLECTION_NAME}' saved to: {CHROMA_PATH}")
print("   ✅ Ready for RAG! Use the same embedding model for queries.")
# Out:
# 🧬 Generating embeddings and storing in ChromaDB (this may take a while)...
#   [50/1560] Added batch to ChromaDB
#   [100/1560] Added batch to ChromaDB
#   [150/1560] Added batch to ChromaDB
#   [200/1560] Added batch to ChromaDB
#   [250/1560] Added batch to ChromaDB
#   [300/1560] Added batch to ChromaDB
#   [350/1560] Added batch to ChromaDB
#   [400/1560] Added batch to ChromaDB
#   [450/1560] Added batch to ChromaDB
#   [500/1560] Added batch to ChromaDB
#   [550/1560] Added batch to ChromaDB
#   [600/1560] Added batch to ChromaDB
#   [650/1560] Added batch to ChromaDB
#   [700/1560] Added batch to ChromaDB
#   [750/1560] Added batch to ChromaDB
#   [800/1560] Added batch to ChromaDB
#   [850/1560] Added batch to ChromaDB
#   [900/1560] Added batch to ChromaDB
#   [950/1560] Added batch to ChromaDB
#   [1000/1560] Added batch to ChromaDB
#   [1050/1560] Added batch to ChromaDB
#   [1100/1560] Added batch to ChromaDB
#   [1150/1560] Added batch to ChromaDB
#   [1200/1560] Added batch to ChromaDB
#   [1250/1560] Added batch to ChromaDB
#   [1300/1560] Added batch to ChromaDB
#   [1350/1560] Added batch to ChromaDB
#   [1400/1560] Added batch to ChromaDB
#   [1450/1560] Added batch to ChromaDB
#   [1500/1560] Added batch to ChromaDB
#   [1550/1560] Added batch to ChromaDB
#   [1560/1560] Added batch to ChromaDB
#
# 🎉 Ingestion complete!
#    ChromaDB collection 'Innowing_db' saved to: chroma_db/chroma_db
#    ✅ Ready for RAG! Use the same embedding model for queries.

# %% [markdown]
# ## 2.9. Conclusion & Next Steps
#
# **Congratulations!** 🎉
#
# You have successfully:
# - Created a secure `.env` file to protect your API key
# - Chunked raw website content into pieces
# - Generated embeddings using Azure OpenAI
# - Built a persistent vector database with ChromaDB
#
# Your `Innowing_db` is now ready to power a **Retrieval-Augmented Generation (RAG)** chatbot.
#
# ### Possible Next Steps
# 1. Experiment with different chunk sizes or embedding models
# 2. Try chunking based on other metrics, like indices etc.
